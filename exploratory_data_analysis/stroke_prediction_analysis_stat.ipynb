# %%
# import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pathlib import Path
from collections import Counter
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
import seaborn as sns

# %% [markdown]
# ## Read in the Clean CSV File

# %%
# Create a DataFrame for the healthcare-dataset-stroke-data.csv. 
stroke_df = pd.read_csv('../resources/clean_strings_stroke_df.csv', index_col=False)
stroke_df.head()
# Out:
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0   9046    Male   67             0              1          Yes
# 1  31112    Male   80             0              1          Yes
# 2  60182  Female   49             0              0          Yes
# 3   1665  Female   79             1              0          Yes
# 4  56669    Male   81             0              0          Yes
#
#        work_type Residence_type  avg_glucose_level  bmi   smoking_status  \
# 0        Private          Urban                228   36  formerly smoked
# 1        Private          Rural                105   32     never smoked
# 2        Private          Urban                171   34           smokes
# 3  Self-employed          Rural                174   24     never smoked
# 4        Private          Urban                186   29  formerly smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# id column from dataframe
# Delete id column
del stroke_df['id']

# %%
# confirm removal of id column
stroke_df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1    Male   80             0              1          Yes        Private
# 2  Female   49             0              0          Yes        Private
# 3  Female   79             1              0          Yes  Self-employed
# 4    Male   81             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level  bmi   smoking_status  stroke
# 0          Urban                228   36  formerly smoked       1
# 1          Rural                105   32     never smoked       1
# 2          Urban                171   34           smokes       1
# 3          Rural                174   24     never smoked       1
# 4          Urban                186   29  formerly smoked       1

# %%
# Display a statistical overview of the DataFrame
stroke_df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4909.000000   4909.000000    4909.000000        4909.000000
# mean     42.854145      0.091872       0.049501         104.816052
# std      22.575986      0.288875       0.216934          44.417384
# min       0.000000      0.000000       0.000000          55.000000
# 25%      25.000000      0.000000       0.000000          77.000000
# 50%      44.000000      0.000000       0.000000          91.000000
# 75%      60.000000      0.000000       0.000000         113.000000
# max      82.000000      1.000000       1.000000         271.000000
#
#                bmi       stroke
# count  4909.000000  4909.000000
# mean     28.448564     0.042575
# std       7.843834     0.201917
# min      10.000000     0.000000
# 25%      23.000000     0.000000
# 50%      28.000000     0.000000
# 75%      33.000000     0.000000
# max      97.000000     1.000000

# %%
# count()
# dtypes
# value_counts()
# info()

# %%
# stroke_df.plot(kind="bar") week 5 day 2
